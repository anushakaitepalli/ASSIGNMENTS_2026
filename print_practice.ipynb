# %%
print("Life is like riding a bicycle. To keep your balance, you must keep moving.")
# Out:
# Life is like riding a bicycle. To keep your balance, you must keep moving.

# %%
print("When you undervalue what you do, the world will undervalue who you are.")
# Out:
# When you undervalue what you do, the world will undervalue who you are.

# %%
print("Your life does not get better by chance, it gets better by change.")
# Out:
# Your life does not get better by chance, it gets better by change.

# %%
print("Life isn’t about finding yourself. Life is about creating yourself.")
# Out:
# Life isn’t about finding yourself. Life is about creating yourself.

# %%
print("Better to have an enemy who slaps you in the face than a friend who stabs you in the back.")
# Out:
# Better to have an enemy who slaps you in the face than a friend who stabs you in the back.

# %%
print("Stab the body and it heals, but injure the heart and the wound lasts a lifetime.")
# Out:
# Stab the body and it heals, but injure the heart and the wound lasts a lifetime.

# %%
print("Sometimes we only see how people really feel about us when we stop being useful to them.")
# Out:
# Sometimes we only see how people really feel about us when we stop being useful to them.

# %%
print("You start making good decisions when you realize karma is in your hands.")
# Out:
# You start making good decisions when you realize karma is in your hands.

# %%
print("When you truly understand karma, then you realize you are responsible for everything in your life.")
# Out:
# When you truly understand karma, then you realize you are responsible for everything in your life.

# %%
print("You don’t get what you want; you get what you deserve.")
# Out:
# You don’t get what you want; you get what you deserve.

# %%
print("Life is like riding a bicycle. To keep your balance, you must keep moving.")
print("You don’t get what you want; you get what you deserve.")
# Out:
# Life is like riding a bicycle. To keep your balance, you must keep moving.
# You don’t get what you want; you get what you deserve.

# %%
print("When you undervalue what you do, the world will undervalue who you are.")
print("Your thoughts are seeds, and the harvest you reap will depend on the seeds you plant.")
# Out:
# When you undervalue what you do, the world will undervalue who you are.
# Your thoughts are seeds, and the harvest you reap will depend on the seeds you plant.

# %%
print("Your life does not get better by chance, it gets better by change.")
print("“Master your emotions, or they will master you.")
# Out:
# Your life does not get better by chance, it gets better by change.
# “Master your emotions, or they will master you.

# %%
print("Choose forgiveness over resentment and find freedom in your heart.")
print("Life isn’t about finding yourself. Life is about creating yourself.")
# Out:
# Choose forgiveness over resentment and find freedom in your heart.
# Life isn’t about finding yourself. Life is about creating yourself.

# %%
print("Better to have an enemy who slaps you in the face than a friend who stabs you in the back.")
print("Inner peace begins the moment you choose not to allow another person or event to control your emotions.")
# Out:
# Better to have an enemy who slaps you in the face than a friend who stabs you in the back.
# Inner peace begins the moment you choose not to allow another person or event to control your emotions.

# %%
print("Stab the body and it heals, but injure the heart and the wound lasts a lifetime.")
print("You start making good decisions when you realize karma is in your hands.")
# Out:
# Stab the body and it heals, but injure the heart and the wound lasts a lifetime.
# You start making good decisions when you realize karma is in your hands.

# %%
print("Your life does not get better by chance, it gets better by change.")
print("When you truly understand karma, then you realize you are responsible for everything in your life.")
# Out:
# Your life does not get better by chance, it gets better by change.
# When you truly understand karma, then you realize you are responsible for everything in your life.

# %%
print("Life is like riding a bicycle. To keep your balance, you must keep moving.")
print("Sometimes we only see how people really feel about us when we stop being useful to them.")
# Out:
# Life is like riding a bicycle. To keep your balance, you must keep moving.
# Sometimes we only see how people really feel about us when we stop being useful to them.

# %%
print("Your life does not get better by chance, it gets better by change.")
print("You start making good decisions when you realize karma is in your hands.")
# Out:
# Your life does not get better by chance, it gets better by change.
# You start making good decisions when you realize karma is in your hands.

# %%
print("You don’t get what you want; you get what you deserve.")
print("Your thoughts are seeds, and the harvest you reap will depend on the seeds you plant.")
# Out:
# You don’t get what you want; you get what you deserve.
# Your thoughts are seeds, and the harvest you reap will depend on the seeds you plant.

# %%
print("Your life does not get better by chance, it gets better by change.")
print("Life is like riding a bicycle. To keep your balance, you must keep moving.")
print("You don’t get what you want; you get what you deserve.")
# Out:
# Your life does not get better by chance, it gets better by change.
# Life is like riding a bicycle. To keep your balance, you must keep moving.
# You don’t get what you want; you get what you deserve.

# %%
print("When you undervalue what you do, the world will undervalue who you are.")
print("Your thoughts are seeds, and the harvest you reap will depend on the seeds you plant.")
print("You don’t get what you want; you get what you deserve.")
# Out:
# When you undervalue what you do, the world will undervalue who you are.
# Your thoughts are seeds, and the harvest you reap will depend on the seeds you plant.
# You don’t get what you want; you get what you deserve.

# %%
print("Your life does not get better by chance, it gets better by change.")
print("“Master your emotions, or they will master you.")
print("Stab the body and it heals, but injure the heart and the wound lasts a lifetime.")
# Out:
# Your life does not get better by chance, it gets better by change.
# “Master your emotions, or they will master you.
# Stab the body and it heals, but injure the heart and the wound lasts a lifetime.

# %%
print("Choose forgiveness over resentment and find freedom in your heart.")
print("Life isn’t about finding yourself. Life is about creating yourself.")
print("When you truly understand karma, then you realize you are responsible for everything in your life.")
# Out:
# Choose forgiveness over resentment and find freedom in your heart.
# Life isn’t about finding yourself. Life is about creating yourself.
# When you truly understand karma, then you realize you are responsible for everything in your life.

# %%
print("Better to have an enemy who slaps you in the face than a friend who stabs you in the back.")
print("Inner peace begins the moment you choose not to allow another person or event to control your emotions.")
print("When you undervalue what you do, the world will undervalue who you are.")
# Out:
# Better to have an enemy who slaps you in the face than a friend who stabs you in the back.
# Inner peace begins the moment you choose not to allow another person or event to control your emotions.
# When you undervalue what you do, the world will undervalue who you are.

# %%
print("Stab the body and it heals, but injure the heart and the wound lasts a lifetime.")
print("You start making good decisions when you realize karma is in your hands.")
print("Life isn’t about finding yourself. Life is about creating yourself.")
# Out:
# Stab the body and it heals, but injure the heart and the wound lasts a lifetime.
# You start making good decisions when you realize karma is in your hands.
# Life isn’t about finding yourself. Life is about creating yourself.

# %%
print("Your life does not get better by chance, it gets better by change.")
print("When you truly understand karma, then you realize you are responsible for everything in your life.")
print("Your life does not get better by chance, it gets better by change.")
# Out:
# Your life does not get better by chance, it gets better by change.
# When you truly understand karma, then you realize you are responsible for everything in your life.
# Your life does not get better by chance, it gets better by change.

# %%
print("Life is like riding a bicycle. To keep your balance, you must keep moving.")
print("Sometimes we only see how people really feel about us when we stop being useful to them.")
print("You start making good decisions when you realize karma is in your hands.")
# Out:
# Life is like riding a bicycle. To keep your balance, you must keep moving.
# Sometimes we only see how people really feel about us when we stop being useful to them.
# You start making good decisions when you realize karma is in your hands.

# %%
print("You don’t get what you want; you get what you deserve.")
print("Your thoughts are seeds, and the harvest you reap will depend on the seeds you plant.")
print("You don’t get what you want; you get what you deserve.")
# Out:
# You don’t get what you want; you get what you deserve.
# Your thoughts are seeds, and the harvest you reap will depend on the seeds you plant.
# You don’t get what you want; you get what you deserve.

# %%
print("Life is like riding a bicycle. To keep your balance, you must keep moving.")
print("Sometimes we only see how people really feel about us when we stop being useful to them.")
print("Your life does not get better by chance, it gets better by change.")
# Out:
# Life is like riding a bicycle. To keep your balance, you must keep moving.
# Sometimes we only see how people really feel about us when we stop being useful to them.
# Your life does not get better by chance, it gets better by change.
